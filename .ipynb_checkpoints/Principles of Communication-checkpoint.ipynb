# %% [markdown]
# exported wave file into (x,y) points. Plan is to modulate this voice signal

# %%
'''Importing and Plotting wavefile '''
import matplotlib.pyplot as plt
times = []
amplitude = []
plt.figure(figsize = (17,8))

with open('wavefileimport.txt') as file:
    line = file.readline()
    for line in file:
        t = line.split()
        t = [RR(i) for i in t]
        times.append(t[0])
        amplitude.append(t[1])
k = plt.plot(times,amplitude, label = '$Amplitude vs Time')
plt.ylabel('$Amplitude$')
plt.xlabel('$Time$')
# k  #  Try not to plot using matplot lib dimmag ka chutney hone lagta hai

# %% [markdown]
# This is not a deterministic function of time, so we have to compute a discrete fourier transform of this data. To do that first we have to index it in form 1: value1,2: value2. For this we use the IndexedSequence function.

# %%
'''Calculating Discrete Fourier Transform'''
values = [i[1] for i in points]
number_of_samples = range(len(values)) # the indexed sequence requires an iterable 
s = IndexedSequence(values,number_of_samples)
s.dft()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-08f958c42b7c> in <module>
#       3 number_of_samples = range(len(values)) # the indexed sequence requires an iterable
#       4 s = IndexedSequence(values,number_of_samples)
# ----> 5 s.dft()
#
# /opt/sagemath-9.2/local/lib/python3.7/site-packages/sage/calculus/transforms/dft.py in dft(self, chi)
#     330         if not(J[0] in ZZ):
#     331             G = J[0].parent() ## if J is not a range it is a group G
# --> 332         if J[0] in ZZ and F.base_ring().fraction_field()==QQ:
#     333             ## assumes J is range(N)
#     334             zeta = CyclotomicField(N).gen()
#
# AttributeError: type object 'float' has no attribute 'base_ring'

# %%
# Out:
#   File "<ipython-input-50-d38c799babfa>", line 1
#     points[Integer(0)][]
#                        ^
# SyntaxError: invalid syntax
